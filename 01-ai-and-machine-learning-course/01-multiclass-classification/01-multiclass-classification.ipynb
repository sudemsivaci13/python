# %%
# loading modules
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

# %%
# load dataset
df = sns.load_dataset('penguins')

print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (344, 7)
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    str
#  1   island             344 non-null    str
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 18.9 KB

# %%
# Clean missing values
df = df.dropna()
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
print("Cleaned Dataset Shape:", df.shape)
# Out:
# Cleaned Dataset Shape: (333, 7)

# %%
# Separate features and target variable
X = df.drop('species', axis=1)
y = df['species']

# One-Hot Encode categorical features
X = pd.get_dummies(X, columns=['island', 'sex'], drop_first=True)

# Label Encode target variable
le = LabelEncoder()
y_encoded = le.fit_transform(y)

print(f"Original Classes: {le.classes_}")
print(f"Encoded Classes: {np.unique(y_encoded)}")
# Out:
# Original Classes: ['Adelie' 'Chinstrap' 'Gentoo']
# Encoded Classes: [0 1 2]

# %%
X
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 4              36.7           19.3              193.0       3450.0
# 5              39.3           20.6              190.0       3650.0
# ..              ...            ...                ...          ...
# 338            47.2           13.7              214.0       4925.0
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
#      island_Dream  island_Torgersen  sex_Male
# 0           False              True      True
# 1           False              True     False
# 2           False              True     False
# 4           False              True     False
# 5           False              True      True
# ..            ...               ...       ...
# 338         False             False     False
# 340         False             False     False
# 341         False             False      True
# 342         False             False     False
# 343         False             False      True
#
# [333 rows x 7 columns]

# %%
# Split dataset into training (60%) and testing (40%) sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.4, random_state=42
)

# Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("Training Features Size:", X_train.size)
print("Testing Features Size:", X_test.size)
# Out:
# Training Features Size: 1393
# Testing Features Size: 938

# %%
# Build Neural Network Architecture
model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(8, activation='relu'),
    Dense(3, activation='softmax')
])

# Compile model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# /opt/anaconda3/envs/ai_ortam/lib/python3.11/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 291 (1.14 KB)
#  Trainable params: 291 (1.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Model Training
history = model.fit(
    X_train, y_train,
    epochs=50,
    validation_split=0.3,
    verbose=1
)
# Out:
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.1942 - loss: 1.2342 - val_accuracy: 0.2333 - val_loss: 1.1782
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1942 - loss: 1.1834 - val_accuracy: 0.2333 - val_loss: 1.1382
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1942 - loss: 1.1382 - val_accuracy: 0.2333 - val_loss: 1.1007
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1942 - loss: 1.0978 - val_accuracy: 0.2333 - val_loss: 1.0661
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1942 - loss: 1.0609 - val_accuracy: 0.2333 - val_loss: 1.0348
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1942 - loss: 1.0286 - val_accuracy: 0.2333 - val_loss: 1.0057
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2158 - loss: 0.9988 - val_accuracy: 0.2667 - val_loss: 0.9785
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2878 - loss: 0.9708 - val_accuracy: 0.3167 - val_loss: 0.9529
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3381 - loss: 0.9452 - val_accuracy: 0.3500 - val_loss: 0.9283
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4101 - loss: 0.9207 - val_accuracy: 0.4333 - val_loss: 0.9047
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4748 - loss: 0.8969 - val_accuracy: 0.5167 - val_loss: 0.8816
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5468 - loss: 0.8737 - val_accuracy: 0.6500 - val_loss: 0.8589
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6043 - loss: 0.8509 - val_accuracy: 0.7333 - val_loss: 0.8363
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7194 - loss: 0.8273 - val_accuracy: 0.7667 - val_loss: 0.8137
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7842 - loss: 0.8044 - val_accuracy: 0.9000 - val_loss: 0.7912
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8273 - loss: 0.7806 - val_accuracy: 0.9333 - val_loss: 0.7684
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8345 - loss: 0.7574 - val_accuracy: 0.9333 - val_loss: 0.7451
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8561 - loss: 0.7334 - val_accuracy: 0.9500 - val_loss: 0.7216
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8849 - loss: 0.7092 - val_accuracy: 0.9667 - val_loss: 0.6980
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8921 - loss: 0.6848 - val_accuracy: 0.9667 - val_loss: 0.6733
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9065 - loss: 0.6597 - val_accuracy: 0.9833 - val_loss: 0.6474
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9281 - loss: 0.6330 - val_accuracy: 0.9833 - val_loss: 0.6196
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9353 - loss: 0.6045 - val_accuracy: 0.9833 - val_loss: 0.5897
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9640 - loss: 0.5738 - val_accuracy: 0.9833 - val_loss: 0.5590
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9712 - loss: 0.5434 - val_accuracy: 0.9833 - val_loss: 0.5283
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9712 - loss: 0.5114 - val_accuracy: 0.9833 - val_loss: 0.4986
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9784 - loss: 0.4820 - val_accuracy: 1.0000 - val_loss: 0.4688
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9784 - loss: 0.4515 - val_accuracy: 1.0000 - val_loss: 0.4398
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9784 - loss: 0.4222 - val_accuracy: 1.0000 - val_loss: 0.4112
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9856 - loss: 0.3938 - val_accuracy: 1.0000 - val_loss: 0.3838
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9856 - loss: 0.3667 - val_accuracy: 1.0000 - val_loss: 0.3581
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9784 - loss: 0.3412 - val_accuracy: 1.0000 - val_loss: 0.3339
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9856 - loss: 0.3175 - val_accuracy: 1.0000 - val_loss: 0.3117
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9928 - loss: 0.2957 - val_accuracy: 1.0000 - val_loss: 0.2914
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9928 - loss: 0.2757 - val_accuracy: 1.0000 - val_loss: 0.2728
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9928 - loss: 0.2571 - val_accuracy: 1.0000 - val_loss: 0.2554
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.2396 - val_accuracy: 1.0000 - val_loss: 0.2395
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.2239 - val_accuracy: 1.0000 - val_loss: 0.2251
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.2093 - val_accuracy: 1.0000 - val_loss: 0.2119
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1959 - val_accuracy: 1.0000 - val_loss: 0.2000
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1835 - val_accuracy: 1.0000 - val_loss: 0.1882
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1718 - val_accuracy: 1.0000 - val_loss: 0.1773
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1612 - val_accuracy: 1.0000 - val_loss: 0.1664
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1511 - val_accuracy: 1.0000 - val_loss: 0.1567
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1419 - val_accuracy: 1.0000 - val_loss: 0.1476
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1333 - val_accuracy: 1.0000 - val_loss: 0.1391
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.1252 - val_accuracy: 1.0000 - val_loss: 0.1307
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1178 - val_accuracy: 1.0000 - val_loss: 0.1230
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1110 - val_accuracy: 1.0000 - val_loss: 0.1161
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.1048 - val_accuracy: 1.0000 - val_loss: 0.1101

# %%
# Evaluate on Test Data
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"\nTest Accuracy: {test_acc * 100:.2f}%")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9851 - loss: 0.1019
#
# Test Accuracy: 98.51%

# %%
# Plot Loss and Accuracy Curves
plt.figure(figsize=(12, 5))

# %%
# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
# Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curves')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Generate Predictions and Evaluate Metrics
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Overall Accuracy: {accuracy:.4f}")
print(f"F1-Score: {f1:.4f}\n")
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted Species')
plt.ylabel('Actual Species')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Overall Accuracy: 0.9851
# F1-Score: 0.9849
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Adelie       0.97      1.00      0.98        65
#    Chinstrap       1.00      0.93      0.96        27
#       Gentoo       1.00      1.00      1.00        42
#
#     accuracy                           0.99       134
#    macro avg       0.99      0.98      0.98       134
# weighted avg       0.99      0.99      0.98       134

# %%
# Single Sample Inference
single_sample = X_test[0:1]
prediction_probs = model.predict(single_sample)
predicted_class_index = np.argmax(prediction_probs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
predicted_species = le.inverse_transform([predicted_class_index])[0]
actual_species = le.inverse_transform([y_test[0]])[0]

# %%
print(f"Class Probabilities: {prediction_probs}")
print(f"Predicted Species: {predicted_species}")
print(f"Actual Species: {actual_species}")
# Out:
# Class Probabilities: [[0.69772726 0.29273853 0.00953429]]
# Predicted Species: Adelie
# Actual Species: Adelie
